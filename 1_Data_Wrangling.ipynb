# %%
import boto3
import json
import pandas as pd
from boto3 import client

# %%
# Get list of Rekognition responses in responses folder of s3 bucket

s3r = boto3.resource('s3')
bucket = s3r.Bucket('judge-a-book')
files_in_bucket = list(bucket.objects.all())

obj_list = [obj.key for obj in files_in_bucket if obj.key.startswith('responses/') and obj.key.endswith('json')]

# %%
# Extract label information from Rekognition responses
conn = client('s3')
res_list = []
for key in obj_list:
    response = conn.get_object(Bucket='judge-a-book', Key=key)
    text = response["Body"].read().decode()
    res_list.append((key, json.loads(text)))

# %%
res_list
# Out:
# [('responses/0001642081.json',
#   {'Labels': [{'Name': 'Text',
#      'Confidence': 99.81629943847656,
#      'Instances': [],
#      'Parents': []},
#     {'Name': 'Menu',
#      'Confidence': 88.78952026367188,
#      'Instances': [{'BoundingBox': {'Width': 0.9102855324745178,
#         'Height': 0.9439492225646973,
#         'Left': 0.03298455476760864,
#         'Top': 0.032055750489234924},
#        'Confidence': 85.45950317382812}],
#      'Parents': [{'Name': 'Text'}]},
#     {'Name': 'Label',
#      'Confidence': 86.8148422241211,
#      'Instances': [],
#      'Parents': [{'Name': 'Text'}]},
#     {'Name': 'Paper',
#      'Confidence': 72.81261444091797,
#      'Instances': [],
#      'Parents': []},
#     {'Name': 'Poster',
#      'Confidence': 71.39962768554688,
#      'Instances': [],
#      'Parents': [{'Name': 'Advertisement'}]},
#     {'Name': 'Advertisement',
#      'Confidence': 71.39962768554688,
#      'Instances': [],
#      'Parents': []},
#     {'Name': 'Flyer',
#      'Confidence': 63.58919906616211,
#      'Instances': [],
#      'Parents': [{'Name': 'Paper'},
#       {'Name': 'Poster'},
#       {'Name': 'Advertisement'}]},
#     {'Name': 'Brochure',
#      'Confidence': 63.58919906616211,
#      'Instances': [],
#      'Parents': [{'Name': 'Paper'},
#       {'Name': 'Poster'},
#       {'Name': 'Advertisement'}]},
#     {'Name': 'Page',
#      'Confidence': 57.10538101196289,
#      'Instances': [],
#      'Parents': [{'Name': 'Text'}]}],
#    'LabelModelVersion': '2.0',
#    'ResponseMetadata': {'RequestId': 'f35e61d4-6510-4dae-a68f-78a63644a608',
#     'HTTPStatusCode': 200,
#     'HTTPHeaders': {'content-type': 'application/x-amz-json-1.1',
#      'date': 'Thu, 18 Jun 2020 00:30:12 GMT',
#      'x-amzn-requestid': 'f35e61d4-6510-4dae-a68f-78a63644a608',
#      'content-length': '1074',
#      'connection': 'keep-alive'},
#     'RetryAttempts': 0}}),
#  ('responses/000171287X.json',
#   {'Labels': [{'Name': 'Label',
#      'Confidence': 99.28236389160156,
#      'Instances': [],
#      'Parents': [{'Name': 'Text'}]},
#     {'Name': 'Text',
#      'Confidence': 99.28236389160156,
#      'Instances': [],
#      'Parents': []},
#     {'Name': 'Advertisement',
#      'Confidence': 91.78839874267578,
#      'Instances': [],
#      'Parents': []},
#     {'Name': 'Poster',
#      'Confidence': 90.03909301757812,
#      'Instances': [],
#      'Parents': [{'Name': 'Advertisement'}]},
#     {'Name': 'Paper',
#      'Confidence': 75.10649108886719,
#      'Instances': [],
#      'Parents': []},
#     {'Name': 'Flyer',
#      'Confidence': 75.10649108886719,
#      'Instances': [],
#      'Parents': [{'Name': 'Poster'},
#       {'Name': 'Paper'},
#       {'Name': 'Advertisement'}]},
#     {'Name': 'Brochure',
#      'Confidence': 75.10649108886719,
#      'Instances': [],
#      'Parents': [{'Name': 'Poster'},
#       {'Name': 'Paper'},
#       {'Name': 'Advertisement'}]},
#     {'Name': 'Beverage',
#      'Confidence': 64.3319091796875,
#      'Instances': [],
#      'Parents': []},
#     {'Name': 'Drink',
#      'Confidence': 64.3319091796875,
#      'Instances': [],
#      'Parents': []}],
#    'LabelModelVersion': '2.0',
#    'ResponseMetadata': {'RequestId': '086d7b57-ac39-4a4e-bdc3-60ea8c146ea5',
#     'HTTPStatusCode': 200,
#     'HTTPHeaders': {'content-type': 'application/x-amz-json-1.1',
#      'date': 'Thu, 18 Jun 2020 00:30:12 GMT',
#      'x-amzn-requestid': '086d7b57-ac39-4a4e-bdc3-60ea8c146ea5',
#      'content-length': '891',
#      'connection': 'keep-alive'},
#     'RetryAttempts': 0}}),
#  ('responses/000171323X.json',
#   {'Labels': [{'Name': 'Advertisement',
#      'Confidence': 99.17513275146484,
#      'Instances': [],
#      'Parents': []},
#     {'Name': 'Poster',
#      'Confidence': 98.7679214477539,
#      'Instances': [],
#      'Parents': [{'Name': 'Advertisement'}]},
#     {'Name': 'Paper',
#      'Confidence': 97.64335632324219,
#      'Instances': [],
#      'Parents': []},
#     {'Name': 'Brochure',
#      'Confidence': 97.64335632324219,
#      'Instances': [],
#      'Parents': [{'Name': 'Advertisement'},
#       {'Name': 'Poster'},
#       {'Name': 'Paper'}]},
#     {'Name': 'Flyer',
#      'Confidence': 97.64335632324219,
#      'Instances': [{'BoundingBox': {'Width': 0.9921875,
#         'Height': 0.9413777589797974,
#         'Left': 0.0,
#         'Top': 0.02942657470703125},
#        'Confidence': 54.34517288208008}],
#      'Parents': [{'Name': 'Advertisement'},
#       {'Name': 'Poster'},
#       {'Name': 'Paper'}]},
#     {'Name': 'Book',
#      'Confidence': 68.79200744628906,
#      'Instances': [],
#      'Parents': []},
#     {'Name': 'Person',
#      'Confidence': 66.04420471191406,
#      'Instances': [{'BoundingBox': {'Width': 0.5160742998123169,
#         'Height': 0.5792682766914368,
#         'Left': 0.0477432906627655,
#         'Top': 0.324876070022583},
#        'Confidence': 61.29741668701172}],
#      'Parents': []},
#     {'Name': 'Human',
#      'Confidence': 66.04420471191406,
#      'Instances': [],
#      'Parents': []}],
#    'LabelModelVersion': '2.0',
#    'ResponseMetadata': {'RequestId': 'eb18c983-7f2a-40b2-b6fa-e2e64ae01fa0',
#     'HTTPStatusCode': 200,
#     'HTTPHeaders': {'content-type': 'application/x-amz-json-1.1',
#      'date': 'Thu, 18 Jun 2020 00:30:13 GMT',
#      'x-amzn-requestid': 'eb18c983-7f2a-40b2-b6fa-e2e64ae01fa0',
#      'content-length': '1083',
#      'connection': 'keep-alive'},
#     'RetryAttempts': 0}}),
#  ('responses/0001713361.json',
#   {'Labels': [{'Name': 'Advertisement',
#      'Confidence': 96.0488052368164,
#      'Instances': [],
#      'Parents': []},
#     {'Name': 'Poster',
#      'Confidence': 95.60458374023438,
#      'Instances': [],
#      'Parents': [{'Name': 'Advertisement'}]},
#     {'Name': 'Label',
#      'Confidence': 90.5382080078125,
#      'Instances': [],
#      'Parents': [{'Name': 'Text'}]},
#     {'Name': 'Text',
#      'Confidence': 90.5382080078125,
#      'Instances': [],
#      'Parents': []},
#     {'Name': 'Paper',
#      'Confidence': 87.68148040771484,
#      'Instances': [],
#      'Parents': []},
#     {'Name': 'Brochure',
#      'Confidence': 87.68148040771484,
#      'Instances': [],
#      'Parents': [{'Name': 'Advertisement'},
#       {'Name': 'Poster'},
#       {'Name': 'Paper'}]},
#     {'Name': 'Flyer',
#      'Confidence': 87.68148040771484,
#      'Instances': [{'BoundingBox': {'Width': 0.9921875,
#         'Height': 0.9601335525512695,
#         'Left': 0.0,
#         'Top': 0.03418463096022606},
#        'Confidence': 52.22870635986328}],
#      'Parents': [{'Name': 'Advertisement'},
#       {'Name': 'Poster'},
#       {'Name': 'Paper'}]},
#     {'Name': 'Mammal',
#      'Confidence': 75.886962890625,
#      'Instances': [],
#      'Parents': [{'Name': 'Animal'}]},
#     {'Name': 'Animal',
#      'Confidence': 75.886962890625,
#      'Instances': [],
#      'Parents': []},
#     {'Name': 'Person',
#      'Confidence': 65.44263458251953,
#      'Instances': [{'BoundingBox': {'Width': 0.1319410800933838,
#         'Height': 0.1045706495642662,
#         'Left': 0.7550886273384094,
#         'Top': 0.06486702710390091},
#        'Confidence': 65.44263458251953}],
#      'Parents': []}],
#    'LabelModelVersion': '2.0',
#    'ResponseMetadata': {'RequestId': 'bd33e735-6525-4bc7-865c-4ffc8bc43284',
#     'HTTPStatusCode': 200,
#     'HTTPHeaders': {'content-type': 'application/x-amz-json-1.1',
#      'date': 'Thu, 18 Jun 2020 00:30:13 GMT',
#      'x-amzn-requestid': 'bd33e735-6525-4bc7-865c-4ffc8bc43284',
#      'content-length': '1265',
#      'connection': 'keep-alive'},
#     'RetryAttempts': 0}}),
#  ('responses/0001953184.json',
#   {'Labels': [{'Name': 'Text',
#      'Confidence': 92.14745330810547,
#      'Instances': [],
#      'Parents': []},
#     {'Name': 'Page',
#      'Confidence': 90.98463439941406,
#      'Instances': [],
#      'Parents': [{'Name': 'Text'}]},
#     {'Name': 'Plot',
#      'Confidence': 74.37047576904297,
#      'Instances': [],
#      'Parents': []},
#     {'Name': 'Diagram',
#      'Confidence': 62.163936614990234,
#      'Instances': [],
#      'Parents': []},
#     {'Name': 'Home Decor',
#      'Confidence': 60.34675598144531,
#      'Instances': [],
#      'Parents': []}],
#    'LabelModelVersion': '2.0',
#    'ResponseMetadata': {'RequestId': '44c4a562-40e2-429b-9a0c-443546502082',
#     'HTTPStatusCode': 200,
#     'HTTPHeaders': {'content-type': 'application/x-amz-json-1.1',
#      'date': 'Thu, 18 Jun 2020 00:30:13 GMT',
#      'x-amzn-requestid': '44c4a562-40e2-429b-9a0c-443546502082',
#      'content-length': '438',
#      'connection': 'keep-alive'},
#     'RetryAttempts': 0}}),
#  ('responses/0001982346.json',
#   {'Labels': [{'Name': 'Human',
#      'Confidence': 99.13249969482422,
#      'Instances': [],
#      'Parents': []},
#     {'Name': 'Person',
#      'Confidence': 99.13249969482422,
#      'Instances': [{'BoundingBox': {'Width': 0.2289142608642578,
#         'Height': 0.2527164816856384,
#         'Left': 0.5839964151382446,
#         'Top': 0.360174298286438},
#        'Confidence': 99.13249969482422},
#       {'BoundingBox': {'Width': 0.0785805881023407,
#         'Height': 0.09270909428596497,
#         'Left': 0.4606311619281769,
#         'Top': 0.4188905358314514},
#        'Confidence': 82.59453582763672}],
#      'Parents': []},
#     {'Name': 'Book',
#      'Confidence': 83.92427825927734,
#      'Instances': [],
#      'Parents': []},
#     {'Name': 'Paper',
#      'Confidence': 81.29755401611328,
#      'Instances': [],
#      'Parents': []},
#     {'Name': 'Poster',
#      'Confidence': 81.29755401611328,
#      'Instances': [],
#      'Parents': [{'Name': 'Advertisement'}]},
#     {'Name': 'Flyer',
#      'Confidence': 81.29755401611328,
#      'Instances': [{'BoundingBox': {'Width': 0.8866550922393799,
#         'Height': 0.9225945472717285,
#         'Left': 0.0562378466129303,
#         'Top': 0.05325007811188698},
#        'Confidence': 81.29755401611328}],
#      'Parents': [{'Name': 'Poster'},
#       {'Name': 'Paper'},
#       {'Name': 'Advertisement'}]},
#     {'Name': 'Advertisement',
#      'Confidence': 81.29755401611328,
#      'Instances': [],
#      'Parents': []},
#     {'Name': 'Comics',
#      'Confidence': 79.22827911376953,
#      'Instances': [],
#      'Parents': [{'Name': 'Book'}]},
#     {'Name': 'Jigsaw Puzzle',
#      'Confidence': 57.19833755493164,
#      'Instances': [],
#      'Parents': [{'Name': 'Game'}, {'Name': 'Person'}]},
#     {'Name': 'Game',
#      'Confidence': 57.19833755493164,
#      'Instances': [],
#      'Parents': [{'Name': 'Person'}]}],
#    'LabelModelVersion': '2.0',
#    'ResponseMetadata': {'RequestId': '43505704-430d-4825-94a7-c4bbf8419302',
#     'HTTPStatusCode': 200,
#     'HTTPHeaders': {'content-type': 'application/x-amz-json-1.1',
#      'date': 'Thu, 18 Jun 2020 00:30:15 GMT',
#      'x-amzn-requestid': '43505704-430d-4825-94a7-c4bbf8419302',
#      'content-length': '1427',
#      'connection': 'keep-alive'},
#     'RetryAttempts': 0}}),
#  ('responses/0002007525.json',
#   {'Labels': [{'Name': 'Text',
#      'Confidence': 99.12823486328125,
#      'Instances': [],
#      'Parents': []},
#     {'Name': 'Paper',
#      'Confidence': 89.24150848388672,
#      'Instances': [],
#      'Parents': []},
#     {'Name': 'Page',
#      'Confidence': 74.44605255126953,
#      'Instances': [],
#      'Parents': [{'Name': 'Text'}]},
#     {'Name': 'Poster',
#      'Confidence': 62.595664978027344,
#      'Instances': [],
#      'Parents': [{'Name': 'Advertisement'}]},
#     {'Name': 'Advertisement',
#      'Confidence': 62.595664978027344,
#      'Instances': [],
#      'Parents': []},
#     {'Name': 'Business Card',
#      'Confidence': 62.3709831237793,
#      'Instances': [],
#      'Parents': [{'Name': 'Paper'}, {'Name': 'Text'}]},
#     {'Name': 'Brochure',
#      'Confidence': 57.955448150634766,
#      'Instances': [],
#      'Parents': [{'Name': 'Poster'},
#       {'Name': 'Advertisement'},
#       {'Name': 'Paper'}]},
#     {'Name': 'Flyer',
#      'Confidence': 57.955448150634766,
#      'Instances': [],
#      'Parents': [{'Name': 'Poster'},
#       {'Name': 'Advertisement'},
#       {'Name': 'Paper'}]}],
#    'LabelModelVersion': '2.0',
#    'ResponseMetadata': {'RequestId': '9ea85414-52d0-415e-8a6d-32b7d7a0caa0',
#     'HTTPStatusCode': 200,
#     'HTTPHeaders': {'content-type': 'application/x-amz-json-1.1',
#      'date': 'Thu, 18 Jun 2020 00:30:15 GMT',
#      'x-amzn-requestid': '9ea85414-52d0-415e-8a6d-32b7d7a0caa0',
#      'content-length': '856',
#      'connection': 'keep-alive'},
#     'RetryAttempts': 0}}),
#  ('responses/0003300145.json',
#   {'Labels': [{'Name': 'Tarmac',
#      'Confidence': 74.47834777832031,
#      'Instances': [],
#      'Parents': []},
#     {'Name': 'Asphalt',
#      'Confidence': 74.47834777832031,
#      'Instances': [],
#      'Parents': []}],
#    'LabelModelVersion': '2.0',
#    'ResponseMetadata': {'RequestId': '5d88e73a-e511-4bae-93b0-1a20880bffd1',
#     'HTTPStatusCode': 200,
#     'HTTPHeaders': {'content-type': 'application/x-amz-json-1.1',
#      'date': 'Thu, 18 Jun 2020 00:30:17 GMT',
#      'x-amzn-requestid': '5d88e73a-e511-4bae-93b0-1a20880bffd1',
#      'content-length': '193',
#      'connection': 'keep-alive'},
#     'RetryAttempts': 0}}),
#  ('responses/0006392784.json',
#   {'Labels': [{'Name': 'Wood',
#      'Confidence': 89.14877319335938,
#      'Instances': [],
#      'Parents': []},
#     {'Name': 'Hardwood',
#      'Confidence': 84.26363372802734,
#      'Instances': [],
#      'Parents': [{'Name': 'Wood'}]},
#     {'Name': 'Animal',
#      'Confidence': 82.74364471435547,
#      'Instances': [],
#      'Parents': []},
#     {'Name': 'Mammal',
#      'Confidence': 82.43162536621094,
#      'Instances': [],
#      'Parents': [{'Name': 'Animal'}]},
#     {'Name': 'Canine',
#      'Confidence': 75.814453125,
#      'Instances': [],
#      'Parents': [{'Name': 'Animal'}, {'Name': 'Mammal'}]},
#     {'Name': 'Hound',
#      'Confidence': 75.814453125,
#      'Instances': [],
#      'Parents': [{'Name': 'Canine'},
#       {'Name': 'Dog'},
#       {'Name': 'Animal'},
#       {'Name': 'Pet'},
#       {'Name': 'Mammal'}]},
#     {'Name': 'Pet',
#      'Confidence': 75.814453125,
#      'Instances': [],
#      'Parents': [{'Name': 'Animal'}]},
#     {'Name': 'Dog',
#      'Confidence': 75.814453125,
#      'Instances': [],
#      'Parents': [{'Name': 'Canine'},
#       {'Name': 'Animal'},
#       {'Name': 'Pet'},
#       {'Name': 'Mammal'}]},
#     {'Name': 'Furniture',
#      'Confidence': 70.86284637451172,
#      'Instances': [],
#      'Parents': []},
#     {'Name': 'Cabinet',
#      'Confidence': 67.19915771484375,
#      'Instances': [],
#      'Parents': [{'Name': 'Furniture'}]}],
#    'LabelModelVersion': '2.0',
#    'ResponseMetadata': {'RequestId': 'b1ca590f-2ffc-4323-a296-c3fd4c18ce1a',
#     'HTTPStatusCode': 200,
#     'HTTPHeaders': {'content-type': 'application/x-amz-json-1.1',
#      'date': 'Wed, 24 Jun 2020 21:55:25 GMT',
#      'x-amzn-requestid': 'b1ca590f-2ffc-4323-a296-c3fd4c18ce1a',
#      'content-length': '1040',
#      'connection': 'keep-alive'},
#     'RetryAttempts': 0}}),
#  ('responses/000647926X.json',
#   {'Labels': [{'Name': 'Book',
#      'Confidence': 80.41870880126953,
#      'Instances': [],
#      'Parents': []},
#     {'Name': 'Person',
#      'Confidence': 79.38955688476562,
#      'Instances': [{'BoundingBox': {'Width': 0.16413015127182007,
#         'Height': 0.10879173874855042,
#         'Left': 0.2805601954460144,
#         'Top': 0.6792080402374268},
#        'Confidence': 79.38955688476562},
#       {'BoundingBox': {'Width': 0.27036404609680176,
#         'Height': 0.09752561897039413,
#         'Left': 0.5466166734695435,
#         'Top': 0.7094910144805908},
#        'Confidence': 63.10776138305664}],
#      'Parents': []},
#     {'Name': 'Human',
#      'Confidence': 79.38955688476562,
#      'Instances': [],
#      'Parents': []},
#     {'Name': 'Novel',
#      'Confidence': 77.30267333984375,
#      'Instances': [],
#      'Parents': [{'Name': 'Book'}]},
#     {'Name': 'Jar',
#      'Confidence': 68.00849151611328,
#      'Instances': [],
#      'Parents': []},
#     {'Name': 'Art',
#      'Confidence': 67.65055847167969,
#      'Instances': [],
#      'Parents': []},
#     {'Name': 'Vase',
#      'Confidence': 64.68331909179688,
#      'Instances': [],
#      'Parents': [{'Name': 'Jar'}, {'Name': 'Pottery'}]},
#     {'Name': 'Pottery',
#      'Confidence': 64.68331909179688,
#      'Instances': [],
#      'Parents': []}],
#    'LabelModelVersion': '2.0',
#    'ResponseMetadata': {'RequestId': '46715cc9-f125-48f0-aab3-451704f57443',
#     'HTTPStatusCode': 200,
#     'HTTPHeaders': {'content-type': 'application/x-amz-json-1.1',
#      'date': 'Thu, 18 Jun 2020 00:30:17 GMT',
#      'x-amzn-requestid': '46715cc9-f125-48f0-aab3-451704f57443',
#      'content-length': '1004',
#      'connection': 'keep-alive'},
#     'RetryAttempts': 0}}),
#  ('responses/0006608361.json',
#   {'Labels': [{'Name': 'Animal',
#      'Confidence': 91.76812744140625,
#      'Instances': [],
#      'Parents': []},
#     {'Name': 'Bird',
#      'Confidence': 91.76812744140625,
#      'Instances': [{'BoundingBox': {'Width': 0.45454418659210205,
#         'Height': 0.39364176988601685,
#         'Left': 0.12909722328186035,
#         'Top': 0.34540677070617676},
#        'Confidence': 91.76812744140625}],
#      'Parents': [{'Name': 'Animal'}]},
#     {'Name': 'Duck',
#      'Confidence': 89.78804779052734,
#      'Instances': [],
#      'Parents': [{'Name': 'Animal'}, {'Name': 'Bird'}]},
#     {'Name': 'Greeting Card',
#      'Confidence': 55.9539680480957,
#      'Instances': [],
#      'Parents': [{'Name': 'Mail'}, {'Name': 'Envelope'}]},
#     {'Name': 'Mail',
#      'Confidence': 55.9539680480957,
#      'Instances': [],
#      'Parents': [{'Name': 'Envelope'}]},
#     {'Name': 'Envelope',
#      'Confidence': 55.9539680480957,
#      'Instances': [],
#      'Parents': []}],
#    'LabelModelVersion': '2.0',
#    'ResponseMetadata': {'RequestId': 'c1b1e4dc-9dc1-4514-8c34-1991ca722de0',
#     'HTTPStatusCode': 200,
#     'HTTPHeaders': {'content-type': 'application/x-amz-json-1.1',
#      'date': 'Thu, 18 Jun 2020 00:30:17 GMT',
#      'x-amzn-requestid': 'c1b1e4dc-9dc1-4514-8c34-1991ca722de0',
#      'content-length': '762',
#      'connection': 'keep-alive'},
#     'RetryAttempts': 0}}),
#  ('responses/0006608752.json',
#   {'Labels': [{'Name': 'Page',
#      'Confidence': 95.03630065917969,
#      'Instances': [],
#      'Parents': [{'Name': 'Text'}]},
#     {'Name': 'Text',
#      'Confidence': 95.03630065917969,
#      'Instances': [],
#      'Parents': []},
#     {'Name': 'Word',
#      'Confidence': 73.73865509033203,
#      'Instances': [],
#      'Parents': []},
#     {'Name': 'Paper',
#      'Confidence': 64.98131561279297,
#      'Instances': [],
#      'Parents': []},
#     {'Name': 'Poster',
#      'Confidence': 57.10226821899414,
#      'Instances': [],
#      'Parents': [{'Name': 'Advertisement'}]},
#     {'Name': 'Flyer',
#      'Confidence': 57.10226821899414,
#      'Instances': [],
#      'Parents': [{'Name': 'Poster'},
#       {'Name': 'Paper'},
#       {'Name': 'Advertisement'}]},
#     {'Name': 'Brochure',
#      'Confidence': 57.10226821899414,
#      'Instances': [],
#      'Parents': [{'Name': 'Poster'},
#       {'Name': 'Paper'},
#       {'Name': 'Advertisement'}]},
#     {'Name': 'Advertisement',
#      'Confidence': 57.10226821899414,
#      'Instances': [],
#      'Parents': []},
#     {'Name': 'Face',
#      'Confidence': 56.34904861450195,
#      'Instances': [],
#      'Parents': []},
#     {'Name': 'Home Decor',
#      'Confidence': 56.07442092895508,
#      'Instances': [],
#      'Parents': []}],
#    'LabelModelVersion': '2.0',
#    'ResponseMetadata': {'RequestId': 'a965ed96-5094-4b25-afb2-0154f7875db2',
#     'HTTPStatusCode': 200,
#     'HTTPHeaders': {'content-type': 'application/x-amz-json-1.1',
#      'date': 'Wed, 24 Jun 2020 22:26:05 GMT',
#      'x-amzn-requestid': 'a965ed96-5094-4b25-afb2-0154f7875db2',
#      'content-length': '968',
#      'connection': 'keep-alive'},
#     'RetryAttempts': 0}}),
#  ('responses/0006640613.json',
#   {'Labels': [{'Name': 'Texture',
#      'Confidence': 86.61911010742188,
#      'Instances': [],
#      'Parents': []},
#     {'Name': 'White',
#      'Confidence': 86.61911010742188,
#      'Instances': [],
#      'Parents': [{'Name': 'Texture'}]},
#     {'Name': 'Gray',
#      'Confidence': 60.63282012939453,
#      'Instances': [],
#      'Parents': []},
#     {'Name': 'White Board',
#      'Confidence': 59.66282653808594,
#      'Instances': [],
#      'Parents': []},
#     {'Name': 'Text',
#      'Confidence': 58.05023193359375,
#      'Instances': [],
#      'Parents': []},
#     {'Name': 'Apparel',
#      'Confidence': 57.9032096862793,
#      'Instances': [],
#      'Parents': []},
#     {'Name': 'Clothing',
#      'Confidence': 57.9032096862793,
#      'Instances': [],
#      'Parents': []}],
#    'LabelModelVersion': '2.0',
#    'ResponseMetadata': {'RequestId': '9cb7099c-c80f-4f8e-97f2-dcbbc6e0085b',
#     'HTTPStatusCode': 200,
#     'HTTPHeaders': {'content-type': 'application/x-amz-json-1.1',
#      'date': 'Wed, 24 Jun 2020 22:23:51 GMT',
#      'x-amzn-requestid': '9cb7099c-c80f-4f8e-97f2-dcbbc6e0085b',
#      'content-length': '597',
#      'connection': 'keep-alive'},
#     'RetryAttempts': 0}}),
#  ('responses/0006647715.json',
#   {'Labels': [{'Name': 'Person',
#      'Confidence': 96.30020141601562,
#      'Instances': [{'BoundingBox': {'Width': 0.4266814589500427,
#         'Height': 0.29107505083084106,
#         'Left': 0.18803094327449799,
#         'Top': 0.5943410396575928},
#        'Confidence': 96.30020141601562}],
#      'Parents': []},
#     {'Name': 'Human',
#      'Confidence': 96.30020141601562,
#      'Instances': [],
#      'Parents': []},
#     {'Name': 'Book',
#      'Confidence': 84.86079406738281,
#      'Instances': [],
#      'Parents': []},
#     {'Name': 'Text',
#      'Confidence': 82.71319580078125,
#      'Instances': [],
#      'Parents': []},
#     {'Name': 'Leisure Activities',
#      'Confidence': 63.07851028442383,
#      'Instances': [],
#      'Parents': []},
#     {'Name': 'Comics',
#      'Confidence': 56.294044494628906,
#      'Instances': [],
#      'Parents': [{'Name': 'Book'}]},
#     {'Name': 'Mammal',
#      'Confidence': 55.929630279541016,
#      'Instances': [],
#      'Parents': [{'Name': 'Animal'}]},
#     {'Name': 'Animal',
#      'Confidence': 55.929630279541016,
#      'Instances': [],
#      'Parents': []}],
#    'LabelModelVersion': '2.0',
#    'ResponseMetadata': {'RequestId': '99f1514f-8b50-4248-9e91-52dd340de1b0',
#     'HTTPStatusCode': 200,
#     'HTTPHeaders': {'content-type': 'application/x-amz-json-1.1',
#      'date': 'Wed, 24 Jun 2020 21:46:51 GMT',
#      'x-amzn-requestid': '99f1514f-8b50-4248-9e91-52dd340de1b0',
#      'content-length': '852',
#      'connection': 'keep-alive'},
#     'RetryAttempts': 0}}),
#  ('responses/000670428X.json',
#   {'Labels': [{'Name': 'Meal',
#      'Confidence': 70.60669708251953,
#      'Instances': [],
#      'Parents': [{'Name': 'Food'}]},
#     {'Name': 'Food',
#      'Confidence': 70.60669708251953,
#      'Instances': [],
#      'Parents': []},
#     {'Name': 'Sweets',
#      'Confidence': 70.4033203125,
#      'Instances': [],
#      'Parents': [{'Name': 'Food'}]},
#     {'Name': 'Confectionery',
#      'Confidence': 70.4033203125,
#      'Instances': [],
#      'Parents': [{'Name': 'Food'}]},
#     {'Name': 'Figurine',
#      'Confidence': 69.89850616455078,
#      'Instances': [],
#      'Parents': []},
#     {'Name': 'Dish',
#      'Confidence': 59.06901168823242,
#      'Instances': [],
#      'Parents': [{'Name': 'Meal'}, {'Name': 'Food'}]}],
#    'LabelModelVersion': '2.0',
#    'ResponseMetadata': {'RequestId': '87b60fdd-0f28-40a4-b18e-1b71359545e4',
#     'HTTPStatusCode': 200,
#     'HTTPHeaders': {'content-type': 'application/x-amz-json-1.1',
#      'date': 'Wed, 24 Jun 2020 21:56:09 GMT',
#      'x-amzn-requestid': '87b60fdd-0f28-40a4-b18e-1b71359545e4',
#      'content-length': '571',
#      'connection': 'keep-alive'},
#     'RetryAttempts': 0}}),
#  ('responses/0006704328.json',
#   {'Labels': [{'Name': 'Poster',
#      'Confidence': 91.14080047607422,
#      'Instances': [],
#      'Parents': [{'Name': 'Advertisement'}]},
#     {'Name': 'Advertisement',
#      'Confidence': 91.14080047607422,
#      'Instances': [],
#      'Parents': []},
#     {'Name': 'Human',
#      'Confidence': 85.89881134033203,
#      'Instances': [],
#      'Parents': []},
#     {'Name': 'Person',
#      'Confidence': 85.89881134033203,
#      'Instances': [{'BoundingBox': {'Width': 0.3404414653778076,
#         'Height': 0.3764934241771698,
#         'Left': 0.5494447350502014,
#         'Top': 0.4156099855899811},
#        'Confidence': 85.89881134033203},
#       {'BoundingBox': {'Width': 0.2514265477657318,
#         'Height': 0.21647830307483673,
#         'Left': 0.30283883213996887,
#         'Top': 0.5276563763618469},
#        'Confidence': 64.54645538330078},
#       {'BoundingBox': {'Width': 0.24084776639938354,
#         'Height': 0.29767611622810364,
#         'Left': 0.09953772276639938,
#         'Top': 0.4804424047470093},
#        'Confidence': 52.302146911621094}],
#      'Parents': []},
#     {'Name': 'Book',
#      'Confidence': 76.88026428222656,
#      'Instances': [],
#      'Parents': []},
#     {'Name': 'Art',
#      'Confidence': 68.3592758178711,
#      'Instances': [],
#      'Parents': []},
#     {'Name': 'Novel',
#      'Confidence': 65.11650848388672,
#      'Instances': [],
#      'Parents': [{'Name': 'Book'}]},
#     {'Name': 'Paper',
#      'Confidence': 61.59137725830078,
#      'Instances': [],
#      'Parents': []},
#     {'Name': 'Brochure',
#      'Confidence': 61.59137725830078,
#      'Instances': [],
#      'Parents': [{'Name': 'Paper'},
#       {'Name': 'Advertisement'},
#       {'Name': 'Poster'}]},
#     {'Name': 'Flyer',
#      'Confidence': 61.59137725830078,
#      'Instances': [],
#      'Parents': [{'Name': 'Paper'},
#       {'Name': 'Advertisement'},
#       {'Name': 'Poster'}]}],
#    'LabelModelVersion': '2.0',
#    'ResponseMetadata': {'RequestId': 'dea914e7-d2a0-42a2-93c2-b78da0186587',
#     'HTTPStatusCode': 200,
#     'HTTPHeaders': {'content-type': 'application/x-amz-json-1.1',
#      'date': 'Wed, 24 Jun 2020 21:44:10 GMT',
#      'x-amzn-requestid': 'dea914e7-d2a0-42a2-93c2-b78da0186587',
#      'content-length': '1434',
#      'connection': 'keep-alive'},
#     'RetryAttempts': 0}}),
#  ('responses/0006708013.json',
#   {'Labels': [{'Name': 'Paper',
#      'Confidence': 74.31752014160156,
#      'Instances': [],
#      'Parents': []},
#     {'Name': 'Advertisement',
#      'Confidence': 69.8421401977539,
#      'Instances': [],
#      'Parents': []},
#     {'Name': 'Poster',
#      'Confidence': 69.8421401977539,
#      'Instances': [],
#      'Parents': [{'Name': 'Advertisement'}]},
#     {'Name': 'Flyer',
#      'Confidence': 60.13068389892578,
#      'Instances': [],
#      'Parents': [{'Name': 'Paper'},
#       {'Name': 'Advertisement'},
#       {'Name': 'Poster'}]},
#     {'Name': 'Brochure',
#      'Confidence': 60.13068389892578,
#      'Instances': [],
#      'Parents': [{'Name': 'Paper'},
#       {'Name': 'Advertisement'},
#       {'Name': 'Poster'}]}],
#    'LabelModelVersion': '2.0',
#    'ResponseMetadata': {'RequestId': 'f1f08498-47cf-421b-aeb3-f1c2a0dad8fc',
#     'HTTPStatusCode': 200,
#     'HTTPHeaders': {'content-type': 'application/x-amz-json-1.1',
#      'date': 'Wed, 24 Jun 2020 22:13:22 GMT',
#      'x-amzn-requestid': 'f1f08498-47cf-421b-aeb3-f1c2a0dad8fc',
#      'content-length': '570',
#      'connection': 'keep-alive'},
#     'RetryAttempts': 0}}),
#  ('responses/0006709931.json',
#   {'Labels': [{'Name': 'Person',
#      'Confidence': 91.77623748779297,
#      'Instances': [{'BoundingBox': {'Width': 0.3695613145828247,
#         'Height': 0.20549948513507843,
#         'Left': 0.1812504678964615,
#         'Top': 0.6692779064178467},
#        'Confidence': 91.77623748779297},
#       {'BoundingBox': {'Width': 0.24599862098693848,
#         'Height': 0.22869160771369934,
#         'Left': 0.7441338896751404,
#         'Top': 0.4655286967754364},
#        'Confidence': 76.18455505371094},
#       {'BoundingBox': {'Width': 0.4038655757904053,
#         'Height': 0.24330049753189087,
#         'Left': 0.018761292099952698,
#         'Top': 0.6478182077407837},
#        'Confidence': 69.27764892578125}],
#      'Parents': []},
#     {'Name': 'Human',
#      'Confidence': 91.77623748779297,
#      'Instances': [],
#      'Parents': []},
#     {'Name': 'Dragon',
#      'Confidence': 85.24370574951172,
#      'Instances': [],
#      'Parents': []},
#     {'Name': 'Art',
#      'Confidence': 71.5594711303711,
#      'Instances': [],
#      'Parents': []},
#     {'Name': 'Novel',
#      'Confidence': 61.70281219482422,
#      'Instances': [],
#      'Parents': [{'Name': 'Book'}]},
#     {'Name': 'Book',
#      'Confidence': 61.70281219482422,
#      'Instances': [],
#      'Parents': []},
#     {'Name': 'Painting',
#      'Confidence': 57.45904541015625,
#      'Instances': [],
#      'Parents': [{'Name': 'Art'}]}],
#    'LabelModelVersion': '2.0',
#    'ResponseMetadata': {'RequestId': '69de303f-a859-4c89-9208-4852884ea943',
#     'HTTPStatusCode': 200,
#     'HTTPHeaders': {'content-type': 'application/x-amz-json-1.1',
#      'date': 'Thu, 18 Jun 2020 00:30:18 GMT',
#      'x-amzn-requestid': '69de303f-a859-4c89-9208-4852884ea943',
#      'content-length': '1070',
#      'connection': 'keep-alive'},
#     'RetryAttempts': 0}}),
#  ('responses/0006714226.json',
#   {'Labels': [{'Name': 'Person',
#      'Confidence': 98.37446594238281,
#      'Instances': [{'BoundingBox': {'Width': 0.8245910406112671,
#         'Height': 0.5073961019515991,
#         'Left': 0.06933560967445374,
#         'Top': 0.4794009327888489},
#        'Confidence': 98.37446594238281}],
#      'Parents': []},
#     {'Name': 'Human',
#      'Confidence': 98.37446594238281,
#      'Instances': [],
#      'Parents': []},
#     {'Name': 'Novel',
#      'Confidence': 91.95872497558594,
#      'Instances': [],
#      'Parents': [{'Name': 'Book'}]},
#     {'Name': 'Book',
#      'Confidence': 91.95872497558594,
#      'Instances': [{'BoundingBox': {'Width': 0.957229733467102,
#         'Height': 0.8784176707267761,
#         'Left': 0.02578568458557129,
#         'Top': 0.06178012117743492},
#        'Confidence': 51.75495529174805}],
#      'Parents': []},
#     {'Name': 'Passport',
#      'Confidence': 62.71312713623047,
#      'Instances': [{'BoundingBox': {'Width': 0.9850190281867981,
#         'Height': 0.91597580909729,
#         'Left': 0.007168471813201904,
#         'Top': 0.03400744870305061},
#        'Confidence': 62.71312713623047}],
#      'Parents': [{'Name': 'Document'},
#       {'Name': 'Text'},
#       {'Name': 'Id Cards'}]},
#     {'Name': 'Id Cards',
#      'Confidence': 62.71312713623047,
#      'Instances': [],
#      'Parents': [{'Name': 'Document'}, {'Name': 'Text'}]},
#     {'Name': 'Text',
#      'Confidence': 62.71312713623047,
#      'Instances': [],
#      'Parents': []},
#     {'Name': 'Document',
#      'Confidence': 62.71312713623047,
#      'Instances': [],
#      'Parents': [{'Name': 'Text'}]}],
#    'LabelModelVersion': '2.0',
#    'ResponseMetadata': {'RequestId': '0c47180b-6185-444b-b329-1c72f061dd51',
#     'HTTPStatusCode': 200,
#     'HTTPHeaders': {'content-type': 'application/x-amz-json-1.1',
#      'date': 'Wed, 24 Jun 2020 22:07:55 GMT',
#      'x-amzn-requestid': '0c47180b-6185-444b-b329-1c72f061dd51',
#      'content-length': '1239',
#      'connection': 'keep-alive'},
#     'RetryAttempts': 0}}),
#  ('responses/0006716733.json',
#   {'Labels': [{'Name': 'Text',
#      'Confidence': 90.25672912597656,
#      'Instances': [],
#      'Parents': []},
#     {'Name': 'Face',
#      'Confidence': 60.17482376098633,
#      'Instances': [],
#      'Parents': []},
#     {'Name': 'Page',
#      'Confidence': 59.88747787475586,
#      'Instances': [],
#      'Parents': [{'Name': 'Text'}]}],
#    'LabelModelVersion': '2.0',
#    'ResponseMetadata': {'RequestId': '0013d6eb-cba2-4b6e-9424-74be11e18f13',
#     'HTTPStatusCode': 200,
#     'HTTPHeaders': {'content-type': 'application/x-amz-json-1.1',
#      'date': 'Wed, 24 Jun 2020 21:49:24 GMT',
#      'x-amzn-requestid': '0013d6eb-cba2-4b6e-9424-74be11e18f13',
#      'content-length': '278',
#      'connection': 'keep-alive'},
#     'RetryAttempts': 0}}),
#  ('responses/0006725813.json',
#   {'Labels': [{'Name': 'Book',
#      'Confidence': 98.46221160888672,
#      'Instances': [],
#      'Parents': []},
#     {'Name': 'Novel',
#      'Confidence': 98.46221160888672,
#      'Instances': [],
#      'Parents': [{'Name': 'Book'}]},
#     {'Name': 'Person',
#      'Confidence': 96.19872283935547,
#      'Instances': [{'BoundingBox': {'Width': 0.4644954204559326,
#         'Height': 0.48832908272743225,
#         'Left': 0.057196423411369324,
#         'Top': 0.35552871227264404},
#        'Confidence': 96.19872283935547}],
#      'Parents': []},
#     {'Name': 'Human',
#      'Confidence': 96.19872283935547,
#      'Instances': [],
#      'Parents': []}],
#    'LabelModelVersion': '2.0',
#    'ResponseMetadata': {'RequestId': '9ffceb67-c9d6-4eae-b322-28377a6ec1d3',
#     'HTTPStatusCode': 200,
#     'HTTPHeaders': {'content-type': 'application/x-amz-json-1.1',
#      'date': 'Thu, 18 Jun 2020 00:30:19 GMT',
#      'x-amzn-requestid': '9ffceb67-c9d6-4eae-b322-28377a6ec1d3',
#      'content-length': '515',
#      'connection': 'keep-alive'},
#     'RetryAttempts': 0}}),
#  ('responses/000672583X.json',
#   {'Labels': [{'Name': 'Outdoors',
#      'Confidence': 93.66438293457031,
#      'Instances': [],
#      'Parents': []},
#     {'Name': 'Nature',
#      'Confidence': 93.36581420898438,
#      'Instances': [],
#      'Parents': []},
#     {'Name': 'Furniture',
#      'Confidence': 90.49185943603516,
#      'Instances': [],
#      'Parents': []},
#     {'Name': 'Word',
#      'Confidence': 88.57241821289062,
#      'Instances': [],
#      'Parents': []},
#     {'Name': 'Text',
#      'Confidence': 72.16716766357422,
#      'Instances': [],
#      'Parents': []},
#     {'Name': 'Water',
#      'Confidence': 67.37401580810547,
#      'Instances': [],
#      'Parents': []},
#     {'Name': 'Pool',
#      'Confidence': 66.76029205322266,
#      'Instances': [],
#      'Parents': [{'Name': 'Water'}]},
#     {'Name': 'Purple',
#      'Confidence': 59.56658935546875,
#      'Instances': [],
#      'Parents': []}],
#    'LabelModelVersion': '2.0',
#    'ResponseMetadata': {'RequestId': '760e50c1-cdf7-46e5-8202-3c48d6f64b21',
#     'HTTPStatusCode': 200,
#     'HTTPHeaders': {'content-type': 'application/x-amz-json-1.1',
#      'date': 'Wed, 24 Jun 2020 21:40:34 GMT',
#      'x-amzn-requestid': '760e50c1-cdf7-46e5-8202-3c48d6f64b21',
#      'content-length': '668',
#      'connection': 'keep-alive'},
#     'RetryAttempts': 0}}),
#  ('responses/0006730515.json',
#   {'Labels': [{'Name': 'Dragon',
#      'Confidence': 99.89934539794922,
#      'Instances': [],
#      'Parents': []},
#     {'Name': 'Art',
#      'Confidence': 71.5645523071289,
#      'Instances': [],
#      'Parents': []},
#     {'Name': 'Human',
#      'Confidence': 64.93818664550781,
#      'Instances': [],
#      'Parents': []},
#     {'Name': 'Person',
#      'Confidence': 64.93818664550781,
#      'Instances': [{'BoundingBox': {'Width': 0.9768813252449036,
#         'Height': 0.7160309553146362,
#         'Left': 0.015306174755096436,
#         'Top': 0.1643778532743454},
#        'Confidence': 64.93818664550781}],
#      'Parents': []},
#     {'Name': 'Modern Art',
#      'Confidence': 63.73758316040039,
#      'Instances': [],
#      'Parents': [{'Name': 'Art'}]},
#     {'Name': 'Poster',
#      'Confidence': 58.906105041503906,
#      'Instances': [{'BoundingBox': {'Width': 0.9823697805404663,
#         'Height': 0.9833952784538269,
#         'Left': 0.009817719459533691,
#         'Top': 0.00731533020734787},
#        'Confidence': 51.50067901611328}],
#      'Parents': [{'Name': 'Advertisement'}]},
#     {'Name': 'Advertisement',
#      'Confidence': 58.906105041503906,
#      'Instances': [],
#      'Parents': []}],
#    'LabelModelVersion': '2.0',
#    'ResponseMetadata': {'RequestId': 'e34de89e-f109-452a-b798-da483ee3a905',
#     'HTTPStatusCode': 200,
#     'HTTPHeaders': {'content-type': 'application/x-amz-json-1.1',
#      'date': 'Wed, 24 Jun 2020 21:54:25 GMT',
#      'x-amzn-requestid': 'e34de89e-f109-452a-b798-da483ee3a905',
#      'content-length': '936',
#      'connection': 'keep-alive'},
#     'RetryAttempts': 0}}),
#  ('responses/0006749119.json',
#   {'Labels': [{'Name': 'Person',
#      'Confidence': 99.62432098388672,
#      'Instances': [{'BoundingBox': {'Width': 0.15988802909851074,
#         'Height': 0.1842043101787567,
#         'Left': 0.6554702520370483,
#         'Top': 0.4693317711353302},
#        'Confidence': 99.62432098388672},
#       {'BoundingBox': {'Width': 0.11737537384033203,
#         'Height': 0.11186428368091583,
#         'Left': 0.8206163644790649,
#         'Top': 0.5216250419616699},
#        'Confidence': 98.90736389160156},
#       {'BoundingBox': {'Width': 0.25805753469467163,
#         'Height': 0.33899953961372375,
#         'Left': 0.2275886833667755,
#         'Top': 0.6180729269981384},
#        'Confidence': 98.43646240234375},
#       {'BoundingBox': {'Width': 0.3213043212890625,
#         'Height': 0.33151260018348694,
#         'Left': 0.49623972177505493,
#         'Top': 0.615973949432373},
#        'Confidence': 98.43292999267578},
#       {'BoundingBox': {'Width': 0.20588651299476624,
#         'Height': 0.3417493999004364,
#         'Left': 0.0,
#         'Top': 0.6211958527565002},
#        'Confidence': 98.26273345947266},
#       {'BoundingBox': {'Width': 0.18519222736358643,
#         'Height': 0.1530003696680069,
#         'Left': 0.4946964383125305,
#         'Top': 0.5100061297416687},
#        'Confidence': 97.8592758178711},
#       {'BoundingBox': {'Width': 0.20160579681396484,
#         'Height': 0.3351350724697113,
#         'Left': 0.790475606918335,
#         'Top': 0.6149719953536987},
#        'Confidence': 97.8178482055664},
#       {'BoundingBox': {'Width': 0.1746407449245453,
#         'Height': 0.16874933242797852,
#         'Left': 0.006427012383937836,
#         'Top': 0.5214497447013855},
#        'Confidence': 97.42566680908203},
#       {'BoundingBox': {'Width': 0.12655523419380188,
#         'Height': 0.1303919106721878,
#         'Left': 0.1625361442565918,
#         'Top': 0.47731274366378784},
#        'Confidence': 97.13298034667969},
#       {'BoundingBox': {'Width': 0.0625869631767273,
#         'Height': 0.14504367113113403,
#         'Left': 0.9296005368232727,
#         'Top': 0.4883081614971161},
#        'Confidence': 96.61185455322266},
#       {'BoundingBox': {'Width': 0.15609222650527954,
#         'Height': 0.1790282279253006,
#         'Left': 0.38191086053848267,
#         'Top': 0.4587617814540863},
#        'Confidence': 93.14319610595703},
#       {'BoundingBox': {'Width': 0.1376517415046692,
#         'Height': 0.15510044991970062,
#         'Left': 0.4249269366264343,
#         'Top': 0.6023217439651489},
#        'Confidence': 90.76331329345703},
#       {'BoundingBox': {'Width': 0.24606946110725403,
#         'Height': 0.3652527630329132,
#         'Left': 0.08946436643600464,
#         'Top': 0.605440080165863},
#        'Confidence': 87.72857666015625},
#       {'BoundingBox': {'Width': 0.13794684410095215,
#         'Height': 0.1406812220811844,
#         'Left': 0.7403371334075928,
#         'Top': 0.5978425741195679},
#        'Confidence': 84.33537292480469},
#       {'BoundingBox': {'Width': 0.1459355354309082,
#         'Height': 0.13931620121002197,
#         'Left': 0.27340468764305115,
#         'Top': 0.5160133242607117},
#        'Confidence': 77.8961410522461}],
#      'Parents': []},
#     {'Name': 'Book',
#      'Confidence': 85.99407196044922,
#      'Instances': [],
#      'Parents': []},
#     {'Name': 'Poster',
#      'Confidence': 85.96420288085938,
#      'Instances': [],
#      'Parents': [{'Name': 'Advertisement'}]},
#     {'Name': 'Advertisement',
#      'Confidence': 85.96420288085938,
#      'Instances': [],
#      'Parents': []},
#     {'Name': 'Novel',
#      'Confidence': 67.18707275390625,
#      'Instances': [],
#      'Parents': [{'Name': 'Book'}]},
#     {'Name': 'People',
#      'Confidence': 61.999542236328125,
#      'Instances': [],
#      'Parents': [{'Name': 'Person'}]},
#     {'Name': 'Female',
#      'Confidence': 58.9276237487793,
#      'Instances': [],
#      'Parents': [{'Name': 'Person'}]},
#     {'Name': 'Girl',
#      'Confidence': 58.9276237487793,
#      'Instances': [],
#      'Parents': [{'Name': 'Person'}, {'Name': 'Female'}]},
#     {'Name': 'Flyer',
#      'Confidence': 56.56246566772461,
#      'Instances': [],
#      'Parents': [{'Name': 'Advertisement'}, {'Name': 'Poster'}]},
#     {'Name': 'Teen',
#      'Confidence': 55.155330657958984,
#      'Instances': [],
#      'Parents': [{'Name': 'Person'}]}],
#    'LabelModelVersion': '2.0',
#    'ResponseMetadata': {'RequestId': '8e23ae6e-f723-49e4-8849-208ee468feb5',
#     'HTTPStatusCode': 200,
#     'HTTPHeaders': {'content-type': 'application/x-amz-json-1.1',
#      'date': 'Wed, 24 Jun 2020 21:55:20 GMT',
#      'x-amzn-requestid': '8e23ae6e-f723-49e4-8849-208ee468feb5',
#      'content-length': '3301',
#      'connection': 'keep-alive'},
#     'RetryAttempts': 0}}),
#  ('responses/0006749526.json',
#   {'Labels': [{'Name': 'Person',
#      'Confidence': 88.68096160888672,
#      'Instances': [{'BoundingBox': {'Width': 0.08775711059570312,
#         'Height': 0.09493228048086166,
#         'Left': 0.4848673939704895,
#         'Top': 0.7784201502799988},
#        'Confidence': 88.68096160888672},
#       {'BoundingBox': {'Width': 0.16738361120224,
#         'Height': 0.13896504044532776,
#         'Left': 0.162032812833786,
#         'Top': 0.7937440872192383},
#        'Confidence': 75.11064147949219},
#       {'BoundingBox': {'Width': 0.26485395431518555,
#         'Height': 0.18563447892665863,
#         'Left': 0.6471673250198364,
#         'Top': 0.739463210105896},
#        'Confidence': 51.845741271972656}],
#      'Parents': []},
#     {'Name': 'Human',
#      'Confidence': 88.68096160888672,
#      'Instances': [],
#      'Parents': []},
#     {'Name': 'Poster',
#      'Confidence': 80.64169311523438,
#      'Instances': [],
#      'Parents': [{'Name': 'Advertisement'}]},
#     {'Name': 'Advertisement',
#      'Confidence': 80.64169311523438,
#      'Instances': [],
#      'Parents': []},
#     {'Name': 'Paper',
#      'Confidence': 73.93770599365234,
#      'Instances': [],
#      'Parents': []},
#     {'Name': 'Flyer',
#      'Confidence': 73.93770599365234,
#      'Instances': [],
#      'Parents': [{'Name': 'Poster'},
#       {'Name': 'Paper'},
#       {'Name': 'Advertisement'}]},
#     {'Name': 'Brochure',
#      'Confidence': 73.93770599365234,
#      'Instances': [],
#      'Parents': [{'Name': 'Poster'},
#       {'Name': 'Paper'},
#       {'Name': 'Advertisement'}]},
#     {'Name': 'Finger',
#      'Confidence': 66.5403823852539,
#      'Instances': [],
#      'Parents': []},
#     {'Name': 'Nail',
#      'Confidence': 66.48614501953125,
#      'Instances': [],
#      'Parents': []}],
#    'LabelModelVersion': '2.0',
#    'ResponseMetadata': {'RequestId': '915bf603-133f-4201-86ef-f8440fee0d00',
#     'HTTPStatusCode': 200,
#     'HTTPHeaders': {'content-type': 'application/x-amz-json-1.1',
#      'date': 'Wed, 24 Jun 2020 22:10:39 GMT',
#      'x-amzn-requestid': '915bf603-133f-4201-86ef-f8440fee0d00',
#      'content-length': '1342',
#      'connection': 'keep-alive'},
#     'RetryAttempts': 0}}),
#  ('responses/0006753485.json',
#   {'Labels': [{'Name': 'Text',
#      'Confidence': 99.88088989257812,
#      'Instances': [],
#      'Parents': []},
#     {'Name': 'Banner',
#      'Confidence': 99.88088989257812,
#      'Instances': [],
#      'Parents': [{'Name': 'Text'}]},
#     {'Name': 'Human',
#      'Confidence': 97.9809799194336,
#      'Instances': [],
#      'Parents': []},
#     {'Name': 'Person',
#      'Confidence': 97.9809799194336,
#      'Instances': [{'BoundingBox': {'Width': 0.2908051013946533,
#         'Height': 0.3691871762275696,
#         'Left': 0.7013823986053467,
#         'Top': 0.10125390440225601},
#        'Confidence': 97.9809799194336},
#       {'BoundingBox': {'Width': 0.2636820077896118,
#         'Height': 0.48541462421417236,
#         'Left': 0.7213548421859741,
#         'Top': 0.41200804710388184},
#        'Confidence': 96.62948608398438},
#       {'BoundingBox': {'Width': 0.26248204708099365,
#         'Height': 0.24257051944732666,
#         'Left': 0.7297054529190063,
#         'Top': 0.2933577597141266},
#        'Confidence': 92.873046875},
#       {'BoundingBox': {'Width': 0.21604490280151367,
#         'Height': 0.27556246519088745,
#         'Left': 0.759510338306427,
#         'Top': 0.7160022258758545},
#        'Confidence': 71.00794219970703}],
#      'Parents': []}],
#    'LabelModelVersion': '2.0',
#    'ResponseMetadata': {'RequestId': 'cd387786-e260-4d0f-a107-5137dde5e488',
#     'HTTPStatusCode': 200,
#     'HTTPHeaders': {'content-type': 'application/x-amz-json-1.1',
#      'date': 'Wed, 24 Jun 2020 22:25:15 GMT',
#      'x-amzn-requestid': 'cd387786-e260-4d0f-a107-5137dde5e488',
#      'content-length': '975',
#      'connection': 'keep-alive'},
#     'RetryAttempts': 0}}),
#  ('responses/0006914888.json',
#   {'Labels': [{'Name': 'Person',
#      'Confidence': 98.51663970947266,
#      'Instances': [{'BoundingBox': {'Width': 0.1068677306175232,
#         'Height': 0.11268502473831177,
#         'Left': 0.3758184015750885,
#         'Top': 0.6225037574768066},
#        'Confidence': 98.51663970947266},
#       {'BoundingBox': {'Width': 0.15598952770233154,
#         'Height': 0.10109773278236389,
#         'Left': 0.4647209048271179,
#         'Top': 0.6653757095336914},
#        'Confidence': 97.47447967529297},
#       {'BoundingBox': {'Width': 0.10002708435058594,
#         'Height': 0.09763273596763611,
#         'Left': 0.6215081810951233,
#         'Top': 0.6705610156059265},
#        'Confidence': 95.02194213867188},
#       {'BoundingBox': {'Width': 0.09431838989257812,
#         'Height': 0.043217871338129044,
#         'Left': 0.7379273772239685,
#         'Top': 0.7214818000793457},
#        'Confidence': 61.63340377807617}],
#      'Parents': []},
#     {'Name': 'Advertisement',
#      'Confidence': 97.39136505126953,
#      'Instances': [],
#      'Parents': []},
#     {'Name': 'Poster',
#      'Confidence': 97.39136505126953,
#      'Instances': [],
#      'Parents': [{'Name': 'Advertisement'}]},
#     {'Name': 'Paper',
#      'Confidence': 97.10250091552734,
#      'Instances': [],
#      'Parents': []},
#     {'Name': 'Flyer',
#      'Confidence': 97.10250091552734,
#      'Instances': [{'BoundingBox': {'Width': 0.9536756277084351,
#         'Height': 0.9185567498207092,
#         'Left': 0.030810892581939697,
#         'Top': 0.05381089821457863},
#        'Confidence': 97.10250091552734}],
#      'Parents': [{'Name': 'Advertisement'},
#       {'Name': 'Poster'},
#       {'Name': 'Paper'}]},
#     {'Name': 'Water',
#      'Confidence': 93.07205963134766,
#      'Instances': [],
#      'Parents': []},
#     {'Name': 'Nature',
#      'Confidence': 83.3057632446289,
#      'Instances': [],
#      'Parents': []},
#     {'Name': 'Art',
#      'Confidence': 80.72473907470703,
#      'Instances': [],
#      'Parents': []},
#     {'Name': 'Outdoors',
#      'Confidence': 77.01905822753906,
#      'Instances': [],
#      'Parents': []},
#     {'Name': 'Vehicle',
#      'Confidence': 74.58325958251953,
#      'Instances': [],
#      'Parents': []}],
#    'LabelModelVersion': '2.0',
#    'ResponseMetadata': {'RequestId': '2b8f2ca2-3023-4a40-975f-8f27be2cabea',
#     'HTTPStatusCode': 200,
#     'HTTPHeaders': {'content-type': 'application/x-amz-json-1.1',
#      'date': 'Thu, 18 Jun 2020 00:30:19 GMT',
#      'x-amzn-requestid': '2b8f2ca2-3023-4a40-975f-8f27be2cabea',
#      'content-length': '1678',
#      'connection': 'keep-alive'},
#     'RetryAttempts': 0}}),
#  ('responses/0006925022.json',
#   {'Labels': [{'Name': 'Text',
#      'Confidence': 99.83577728271484,
#      'Instances': [],
#      'Parents': []},
#     {'Name': 'Page',
#      'Confidence': 96.99278259277344,
#      'Instances': [],
#      'Parents': [{'Name': 'Text'}]},
#     {'Name': 'Menu',
#      'Confidence': 86.59673309326172,
#      'Instances': [],
#      'Parents': [{'Name': 'Text'}]},
#     {'Name': 'Paper',
#      'Confidence': 59.7849006652832,
#      'Instances': [],
#      'Parents': []}],
#    'LabelModelVersion': '2.0',
#    'ResponseMetadata': {'RequestId': 'a67ed15f-ac5d-40fc-acfb-27aed958f79d',
#     'HTTPStatusCode': 200,
#     'HTTPHeaders': {'content-type': 'application/x-amz-json-1.1',
#      'date': 'Thu, 18 Jun 2020 00:30:20 GMT',
#      'x-amzn-requestid': 'a67ed15f-ac5d-40fc-acfb-27aed958f79d',
#      'content-length': '368',
#      'connection': 'keep-alive'},
#     'RetryAttempts': 0}}),
#  ('responses/000692946X.json',
#   {'Labels': [{'Name': 'Coin',
#      'Confidence': 89.52069091796875,
#      'Instances': [],
#      'Parents': [{'Name': 'Money'}]},
#     {'Name': 'Money',
#      'Confidence': 89.52069091796875,
#      'Instances': [],
#      'Parents': []},
#     {'Name': 'Nickel',
#      'Confidence': 68.40557861328125,
#      'Instances': [],
#      'Parents': [{'Name': 'Coin'}, {'Name': 'Money'}]}],
#    'LabelModelVersion': '2.0',
#    'ResponseMetadata': {'RequestId': 'bca5fa3c-f413-4858-b1d8-2f8cf4e22084',
#     'HTTPStatusCode': 200,
#     'HTTPHeaders': {'content-type': 'application/x-amz-json-1.1',
#      'date': 'Wed, 24 Jun 2020 21:53:03 GMT',
#      'x-amzn-requestid': 'bca5fa3c-f413-4858-b1d8-2f8cf4e22084',
#      'content-length': '314',
#      'connection': 'keep-alive'},
#     'RetryAttempts': 0}}),
#  ('responses/0006933971.json',
#   {'Labels': [{'Name': 'Human',
# ...
#     {'Name': 'Poster',
#      'Confidence': 96.19300079345703,
#      'Instances': [],
#      'Parents': [{'Name': 'Advertisement'}]},
#     {'Name': 'Paper',
#      'Confidence': 96.19300079345703,
#      'Instances': [],
#      'Parents': []},
#     {'Name': 'Brochure',
#      'Confidence': 96.19300079345703,
#      'Instances': [],
#      'Parents': [{'Name': 'Paper'},
#       {'Name': 'Advertisement'},
#       {'Name': 'Poster'}]},
#     {'Name': 'Book',
#      'Confidence': 67.59357452392578,
#      'Instances': [],
#      'Parents': []},
#     {'Name': 'Crowd',
#      'Confidence': 61.10462188720703,
#      'Instances': [],
#      'Parents': []},
#     {'Name': 'Text',
#      'Confidence': 59.03628158569336,
#      'Instances': [],
#      'Parents': []},
#     {'Name': 'Novel',
#      'Confidence': 55.71979904174805,
#      'Instances': [],
#      'Parents': [{'Name': 'Book'}]}],
#    'LabelModelVersion': '2.0',
#    'ResponseMetadata': {'RequestId': '7114d8de-5ef7-4314-9209-7bf53709be26',
#     'HTTPStatusCode': 200,
#     'HTTPHeaders': {'content-type': 'application/x-amz-json-1.1',
#      'date': 'Wed, 24 Jun 2020 22:00:00 GMT',
#      'x-amzn-requestid': '7114d8de-5ef7-4314-9209-7bf53709be26',
#      'content-length': '1046',
#      'connection': 'keep-alive'},
#     'RetryAttempts': 0}}),
#  ('responses/0152470409.json',
#   {'Labels': [{'Name': 'Text',
#      'Confidence': 99.75287628173828,
#      'Instances': [],
#      'Parents': []},
#     {'Name': 'Id Cards',
#      'Confidence': 97.58507537841797,
#      'Instances': [],
#      'Parents': [{'Name': 'Document'}, {'Name': 'Text'}]},
#     {'Name': 'Document',
#      'Confidence': 97.58507537841797,
#      'Instances': [],
#      'Parents': [{'Name': 'Text'}]},
#     {'Name': 'Passport',
#      'Confidence': 82.41314697265625,
#      'Instances': [{'BoundingBox': {'Width': 0.9921875,
#         'Height': 0.976032555103302,
#         'Left': 0.0,
#         'Top': 0.018085120245814323},
#        'Confidence': 80.94628143310547}],
#      'Parents': [{'Name': 'Id Cards'},
#       {'Name': 'Document'},
#       {'Name': 'Text'}]}],
#    'LabelModelVersion': '2.0',
#    'ResponseMetadata': {'RequestId': '27d4a302-ff33-43fc-ab7d-84779d52441b',
#     'HTTPStatusCode': 200,
#     'HTTPHeaders': {'content-type': 'application/x-amz-json-1.1',
#      'date': 'Wed, 24 Jun 2020 22:12:35 GMT',
#      'x-amzn-requestid': '27d4a302-ff33-43fc-ab7d-84779d52441b',
#      'content-length': '586',
#      'connection': 'keep-alive'},
#     'RetryAttempts': 0}}),
#  ('responses/0152494650.json',
#   {'Labels': [{'Name': 'Novel',
#      'Confidence': 95.8454360961914,
#      'Instances': [],
#      'Parents': [{'Name': 'Book'}]},
#     {'Name': 'Book',
#      'Confidence': 95.8454360961914,
#      'Instances': [],
#      'Parents': []},
#     {'Name': 'Outdoors',
#      'Confidence': 75.58988952636719,
#      'Instances': [],
#      'Parents': []},
#     {'Name': 'Nature',
#      'Confidence': 66.9727554321289,
#      'Instances': [],
#      'Parents': []},
#     {'Name': 'Human',
#      'Confidence': 62.855106353759766,
#      'Instances': [],
#      'Parents': []},
#     {'Name': 'Person',
#      'Confidence': 62.855106353759766,
#      'Instances': [{'BoundingBox': {'Width': 0.03397488594055176,
#         'Height': 0.04575717821717262,
#         'Left': 0.7639415860176086,
#         'Top': 0.6713451743125916},
#        'Confidence': 62.855106353759766},
#       {'BoundingBox': {'Width': 0.02380123734474182,
#         'Height': 0.039915986359119415,
#         'Left': 0.1833818554878235,
#         'Top': 0.6695101857185364},
#        'Confidence': 43.98597717285156}],
#      'Parents': []}],
#    'LabelModelVersion': '2.0',
#    'ResponseMetadata': {'RequestId': 'e2ca7313-0b4a-4f7a-8faf-9242e65b80a0',
#     'HTTPStatusCode': 200,
#     'HTTPHeaders': {'content-type': 'application/x-amz-json-1.1',
#      'date': 'Wed, 24 Jun 2020 22:01:55 GMT',
#      'x-amzn-requestid': 'e2ca7313-0b4a-4f7a-8faf-9242e65b80a0',
#      'content-length': '827',
#      'connection': 'keep-alive'},
#     'RetryAttempts': 0}}),
#  ('responses/0152525955.json',
#   {'Labels': [{'Name': 'Book',
#      'Confidence': 80.9141616821289,
#      'Instances': [],
#      'Parents': []},
#     {'Name': 'Human',
#      'Confidence': 79.27437591552734,
#      'Instances': [],
#      'Parents': []},
#     {'Name': 'Person',
#      'Confidence': 79.27437591552734,
#      'Instances': [{'BoundingBox': {'Width': 0.4687741696834564,
#         'Height': 0.33672356605529785,
#         'Left': 0.20777228474617004,
#         'Top': 0.2912503778934479},
#        'Confidence': 79.27437591552734}],
#      'Parents': []},
#     {'Name': 'Art',
#      'Confidence': 62.213741302490234,
#      'Instances': [],
#      'Parents': []},
#     {'Name': 'Poster',
#      'Confidence': 57.9479866027832,
#      'Instances': [],
#      'Parents': [{'Name': 'Advertisement'}]},
#     {'Name': 'Advertisement',
#      'Confidence': 57.9479866027832,
#      'Instances': [],
#      'Parents': []},
#     {'Name': 'Comics',
#      'Confidence': 55.331825256347656,
#      'Instances': [],
#      'Parents': [{'Name': 'Book'}]}],
#    'LabelModelVersion': '2.0',
#    'ResponseMetadata': {'RequestId': 'ec1fd8f5-ab3a-4980-add4-5b2b0dd845ad',
#     'HTTPStatusCode': 200,
#     'HTTPHeaders': {'content-type': 'application/x-amz-json-1.1',
#      'date': 'Thu, 18 Jun 2020 00:35:45 GMT',
#      'x-amzn-requestid': 'ec1fd8f5-ab3a-4980-add4-5b2b0dd845ad',
#      'content-length': '772',
#      'connection': 'keep-alive'},
#     'RetryAttempts': 0}}),
#  ('responses/015253184X.json',
#   {'Labels': [{'Name': 'Book',
#      'Confidence': 75.5280990600586,
#      'Instances': [],
#      'Parents': []},
#     {'Name': 'Poster',
#      'Confidence': 70.95545196533203,
#      'Instances': [],
#      'Parents': [{'Name': 'Advertisement'}]},
#     {'Name': 'Advertisement',
#      'Confidence': 70.95545196533203,
#      'Instances': [],
#      'Parents': []},
#     {'Name': 'Novel',
#      'Confidence': 68.6574935913086,
#      'Instances': [],
#      'Parents': [{'Name': 'Book'}]},
#     {'Name': 'Paper',
#      'Confidence': 59.844844818115234,
#      'Instances': [],
#      'Parents': []},
#     {'Name': 'Brochure',
#      'Confidence': 58.49925994873047,
#      'Instances': [],
#      'Parents': [{'Name': 'Poster'},
#       {'Name': 'Paper'},
#       {'Name': 'Advertisement'}]},
#     {'Name': 'Flyer',
#      'Confidence': 58.49925994873047,
#      'Instances': [{'BoundingBox': {'Width': 0.9430849552154541,
#         'Height': 0.9425529837608337,
#         'Left': 0.03414583206176758,
#         'Top': 0.05138637498021126},
#        'Confidence': 54.019840240478516}],
#      'Parents': [{'Name': 'Poster'},
#       {'Name': 'Paper'},
#       {'Name': 'Advertisement'}]},
#     {'Name': 'Crowd',
#      'Confidence': 55.56182098388672,
#      'Instances': [],
#      'Parents': []}],
#    'LabelModelVersion': '2.0',
#    'ResponseMetadata': {'RequestId': 'c4e33487-f39f-41cc-b282-4057f6acdb0f',
#     'HTTPStatusCode': 200,
#     'HTTPHeaders': {'content-type': 'application/x-amz-json-1.1',
#      'date': 'Wed, 24 Jun 2020 22:15:25 GMT',
#      'x-amzn-requestid': 'c4e33487-f39f-41cc-b282-4057f6acdb0f',
#      'content-length': '970',
#      'connection': 'keep-alive'},
#     'RetryAttempts': 0}}),
#  ('responses/0152567089.json',
#   {'Labels': [{'Name': 'Person',
#      'Confidence': 72.31849670410156,
#      'Instances': [{'BoundingBox': {'Width': 0.4889637231826782,
#         'Height': 0.6941152811050415,
#         'Left': 0.44030994176864624,
#         'Top': 0.1744934469461441},
#        'Confidence': 72.31849670410156}],
#      'Parents': []},
#     {'Name': 'Human',
#      'Confidence': 72.31849670410156,
#      'Instances': [],
#      'Parents': []},
#     {'Name': 'Art',
#      'Confidence': 55.30062484741211,
#      'Instances': [],
#      'Parents': []},
#     {'Name': 'Novel',
#      'Confidence': 55.29411315917969,
#      'Instances': [],
#      'Parents': [{'Name': 'Book'}]},
#     {'Name': 'Book',
#      'Confidence': 55.29411315917969,
#      'Instances': [],
#      'Parents': []},
#     {'Name': 'Final Fantasy',
#      'Confidence': 55.165611267089844,
#      'Instances': [],
#      'Parents': []}],
#    'LabelModelVersion': '2.0',
#    'ResponseMetadata': {'RequestId': '729ef4c0-ffde-4790-8e8c-941b48022ccd',
#     'HTTPStatusCode': 200,
#     'HTTPHeaders': {'content-type': 'application/x-amz-json-1.1',
#      'date': 'Thu, 18 Jun 2020 00:35:45 GMT',
#      'x-amzn-requestid': '729ef4c0-ffde-4790-8e8c-941b48022ccd',
#      'content-length': '671',
#      'connection': 'keep-alive'},
#     'RetryAttempts': 0}}),
#  ('responses/0152671404.json',
#   {'Labels': [{'Name': 'Novel',
#      'Confidence': 89.41468811035156,
#      'Instances': [],
#      'Parents': [{'Name': 'Book'}]},
#     {'Name': 'Book',
#      'Confidence': 89.41468811035156,
#      'Instances': [],
#      'Parents': []},
#     {'Name': 'Apparel',
#      'Confidence': 66.22219848632812,
#      'Instances': [],
#      'Parents': []},
#     {'Name': 'Pants',
#      'Confidence': 66.22219848632812,
#      'Instances': [],
#      'Parents': [{'Name': 'Clothing'}]},
#     {'Name': 'Clothing',
#      'Confidence': 66.22219848632812,
#      'Instances': [],
#      'Parents': []}],
#    'LabelModelVersion': '2.0',
#    'ResponseMetadata': {'RequestId': 'a3fbcb80-8b9b-4518-9341-b0e2a94a3bcc',
#     'HTTPStatusCode': 200,
#     'HTTPHeaders': {'content-type': 'application/x-amz-json-1.1',
#      'date': 'Wed, 24 Jun 2020 22:27:50 GMT',
#      'x-amzn-requestid': 'a3fbcb80-8b9b-4518-9341-b0e2a94a3bcc',
#      'content-length': '456',
#      'connection': 'keep-alive'},
#     'RetryAttempts': 0}}),
#  ('responses/015271233X.json',
#   {'Labels': [{'Name': 'Poster',
#      'Confidence': 96.72135925292969,
#      'Instances': [],
#      'Parents': [{'Name': 'Advertisement'}]},
#     {'Name': 'Advertisement',
#      'Confidence': 96.72135925292969,
#      'Instances': [],
#      'Parents': []},
#     {'Name': 'Outdoors',
#      'Confidence': 95.65652465820312,
#      'Instances': [],
#      'Parents': []},
#     {'Name': 'Nature',
#      'Confidence': 93.63273620605469,
#      'Instances': [],
#      'Parents': []},
#     {'Name': 'Person',
#      'Confidence': 91.81422424316406,
#      'Instances': [{'BoundingBox': {'Width': 0.31911373138427734,
#         'Height': 0.5188234448432922,
#         'Left': 0.36138516664505005,
#         'Top': 0.380481481552124},
#        'Confidence': 91.81422424316406}],
#      'Parents': []},
#     {'Name': 'Art',
#      'Confidence': 83.02930450439453,
#      'Instances': [],
#      'Parents': []},
#     {'Name': 'Painting',
#      'Confidence': 83.02930450439453,
#      'Instances': [{'BoundingBox': {'Width': 0.9667900800704956,
#         'Height': 0.9660711288452148,
#         'Left': 0.025397390127182007,
#         'Top': 0.017990658059716225},
#        'Confidence': 83.02930450439453}],
#      'Parents': [{'Name': 'Art'}]},
#     {'Name': 'Flyer',
#      'Confidence': 76.47128295898438,
#      'Instances': [],
#      'Parents': [{'Name': 'Poster'}, {'Name': 'Advertisement'}]},
#     {'Name': 'Collage',
#      'Confidence': 75.03961181640625,
#      'Instances': [],
#      'Parents': [{'Name': 'Poster'}, {'Name': 'Advertisement'}]},
#     {'Name': 'Field',
#      'Confidence': 66.29497528076172,
#      'Instances': [],
#      'Parents': []}],
#    'LabelModelVersion': '2.0',
#    'ResponseMetadata': {'RequestId': '14d789a3-2d3d-4d92-a444-b4ec888c4c58',
#     'HTTPStatusCode': 200,
#     'HTTPHeaders': {'content-type': 'application/x-amz-json-1.1',
#      'date': 'Thu, 18 Jun 2020 00:35:45 GMT',
#      'x-amzn-requestid': '14d789a3-2d3d-4d92-a444-b4ec888c4c58',
#      'content-length': '1250',
#      'connection': 'keep-alive'},
#     'RetryAttempts': 0}}),
#  ('responses/0152863990.json',
#   {'Labels': [{'Name': 'Text',
#      'Confidence': 99.99747467041016,
#      'Instances': [],
#      'Parents': []},
#     {'Name': 'Page',
#      'Confidence': 99.99747467041016,
#      'Instances': [],
#      'Parents': [{'Name': 'Text'}]},
#     {'Name': 'Document',
#      'Confidence': 99.894775390625,
#      'Instances': [{'BoundingBox': {'Width': 0.9051425457000732,
#         'Height': 0.882375180721283,
#         'Left': 0.04638093709945679,
#         'Top': 0.08888168632984161},
#        'Confidence': 99.894775390625}],
#      'Parents': [{'Name': 'Text'}]},
#     {'Name': 'Word',
#      'Confidence': 90.80706787109375,
#      'Instances': [],
#      'Parents': []},
#     {'Name': 'Paper',
#      'Confidence': 64.7881851196289,
#      'Instances': [],
#      'Parents': []}],
#    'LabelModelVersion': '2.0',
#    'ResponseMetadata': {'RequestId': 'a46693ba-4a1a-432d-bb4b-1b6646b006b1',
#     'HTTPStatusCode': 200,
#     'HTTPHeaders': {'content-type': 'application/x-amz-json-1.1',
#      'date': 'Wed, 24 Jun 2020 22:01:29 GMT',
#      'x-amzn-requestid': 'a46693ba-4a1a-432d-bb4b-1b6646b006b1',
#      'content-length': '598',
#      'connection': 'keep-alive'},
#     'RetryAttempts': 0}}),
#  ('responses/0152928766.json',
#   {'Labels': [{'Name': 'Person',
#      'Confidence': 99.30500030517578,
#      'Instances': [{'BoundingBox': {'Width': 0.2669541835784912,
#         'Height': 0.38092026114463806,
#         'Left': 0.4294089674949646,
#         'Top': 0.31798598170280457},
#        'Confidence': 99.30500030517578},
#       {'BoundingBox': {'Width': 0.21602606773376465,
#         'Height': 0.36527019739151,
#         'Left': 0.20901712775230408,
#         'Top': 0.36672139167785645},
#        'Confidence': 99.17024230957031},
#       {'BoundingBox': {'Width': 0.08388090133666992,
#         'Height': 0.41733020544052124,
#         'Left': 0.6673187017440796,
#         'Top': 0.24852943420410156},
#        'Confidence': 97.97161865234375}],
#      'Parents': []},
#     {'Name': 'Painting',
#      'Confidence': 94.89798736572266,
#      'Instances': [{'BoundingBox': {'Width': 0.8002958297729492,
#         'Height': 0.7774690985679626,
#         'Left': 0.12442135810852051,
#         'Top': 0.12455058842897415},
#        'Confidence': 94.89798736572266}],
#      'Parents': [{'Name': 'Art'}]},
#     {'Name': 'Art',
#      'Confidence': 94.89798736572266,
#      'Instances': [],
#      'Parents': []},
#     {'Name': 'Text',
#      'Confidence': 87.76570129394531,
#      'Instances': [],
#      'Parents': []},
#     {'Name': 'Book',
#      'Confidence': 84.65815734863281,
#      'Instances': [],
#      'Parents': []},
#     {'Name': 'Novel',
#      'Confidence': 77.7416763305664,
#      'Instances': [],
#      'Parents': [{'Name': 'Book'}]},
#     {'Name': 'Paper',
#      'Confidence': 68.11216735839844,
#      'Instances': [],
#      'Parents': []},
#     {'Name': 'Advertisement',
#      'Confidence': 58.10343933105469,
#      'Instances': [],
#      'Parents': []},
#     {'Name': 'Newspaper',
#      'Confidence': 57.01152038574219,
#      'Instances': [],
#      'Parents': [{'Name': 'Text'}]},
#     {'Name': 'Poster',
#      'Confidence': 56.86187744140625,
#      'Instances': [],
#      'Parents': [{'Name': 'Advertisement'}]}],
#    'LabelModelVersion': '2.0',
#    'ResponseMetadata': {'RequestId': '945376d1-593c-4365-b324-c76ecf70db58',
#     'HTTPStatusCode': 200,
#     'HTTPHeaders': {'content-type': 'application/x-amz-json-1.1',
#      'date': 'Thu, 18 Jun 2020 00:35:46 GMT',
#      'x-amzn-requestid': '945376d1-593c-4365-b324-c76ecf70db58',
#      'content-length': '1504',
#      'connection': 'keep-alive'},
#     'RetryAttempts': 0}}),
#  ('responses/0152985727.json',
#   {'Labels': [{'Name': 'Person',
#      'Confidence': 97.69168853759766,
#      'Instances': [{'BoundingBox': {'Width': 0.6002342700958252,
#         'Height': 0.5538223385810852,
#         'Left': 0.07122156023979187,
#         'Top': 0.3448023200035095},
#        'Confidence': 97.69168853759766}],
#      'Parents': []},
#     {'Name': 'Human',
#      'Confidence': 97.69168853759766,
#      'Instances': [],
#      'Parents': []},
#     {'Name': 'Novel',
#      'Confidence': 94.34768676757812,
#      'Instances': [],
#      'Parents': [{'Name': 'Book'}]},
#     {'Name': 'Book',
#      'Confidence': 94.34768676757812,
#      'Instances': [],
#      'Parents': []},
#     {'Name': 'Art',
#      'Confidence': 71.06855773925781,
#      'Instances': [],
#      'Parents': []}],
#    'LabelModelVersion': '2.0',
#    'ResponseMetadata': {'RequestId': '2b486e94-0f98-40e5-88c1-2c12fbfa8d1e',
#     'HTTPStatusCode': 200,
#     'HTTPHeaders': {'content-type': 'application/x-amz-json-1.1',
#      'date': 'Thu, 18 Jun 2020 00:35:47 GMT',
#      'x-amzn-requestid': '2b486e94-0f98-40e5-88c1-2c12fbfa8d1e',
#      'content-length': '586',
#      'connection': 'keep-alive'},
#     'RetryAttempts': 0}}),
#  ...]

# %%
# Compiles Rekognition label information into DataFrame compatible list format

label_list = []
no_label_list = []
for res in res_list:
    labels = res[1]['Labels']
    if len(labels) == 0:
        ISBN = res[0][10:-5]
        no_label_list.append(ISBN)
    else:
        for label in res[1]['Labels']:
            ISBN = res[0][10:-5]
            Name = label['Name']
            Confidence = label['Confidence']
            Instances = label['Instances']
            numInst = len(label['Instances'])
            label_list.append({'ISBN': ISBN, 
                               'Name': Name, 
                               'Confidence': Confidence, 
                               'Instances': Instances, 
                               'Num_Instances': numInst})
        
# Create DataFrame from label_list

df = pd.DataFrame(label_list)

# %%
no_labels = pd.DataFrame(no_label_list)

# %%
len(no_labels)
# Out:
# 23

# %% [markdown]
# #### Theres 23 book covers that has no labels

# %%
df.head()
# Out:
#          ISBN    Name  Confidence  \
# 0  0001642081    Text   99.816299
# 1  0001642081    Menu   88.789520
# 2  0001642081   Label   86.814842
# 3  0001642081   Paper   72.812614
# 4  0001642081  Poster   71.399628
#
#                                            Instances  Num_Instances
# 0                                                 []              0
# 1  [{'BoundingBox': {'Width': 0.9102855324745178,...              1
# 2                                                 []              0
# 3                                                 []              0
# 4                                                 []              0

# %%
# Import goodreads' children's books dataframe

goodreads = pd.read_json('goodreads_books_children.json', lines=True)
goodreads.head()
# Out:
#          isbn  text_reviews_count    series country_code language_code  \
# 0  1599150603                   7        []           US
# 1  1934876569                   6  [151854]           US
# 2  0590417010                 193        []           US           eng
# 3  0915190575                   4        []           US
# 4  1416904999                   4        []           US
#
#                                      popular_shelves asin is_ebook  \
# 0  [{'count': '56', 'name': 'to-read'}, {'count':...         false
# 1  [{'count': '515', 'name': 'to-read'}, {'count'...         false
# 2  [{'count': '450', 'name': 'to-read'}, {'count'...         false
# 3  [{'count': '8', 'name': 'to-read'}, {'count': ...         false
# 4  [{'count': '8', 'name': 'to-read'}, {'count': ...         false
#
#    average_rating kindle_asin  ... publication_month edition_information  \
# 0            4.13  B00DU10PUG  ...                 9
# 1            4.22              ...                 3
# 2            4.43  B017RORXNI  ...                 9
# 3            4.29              ...
# 4            3.57              ...                 6
#
#   publication_year                                                url  \
# 0             2006  https://www.goodreads.com/book/show/287141.The...
# 1             2009  https://www.goodreads.com/book/show/6066812-al...
# 2             1995  https://www.goodreads.com/book/show/89378.Dog_...
# 3                   https://www.goodreads.com/book/show/3209312-mo...
# 4             2005  https://www.goodreads.com/book/show/1698376.Wh...
#
#                                            image_url  book_id ratings_count  \
# 0  https://s.gr-assets.com/assets/nophoto/book/11...   287141            46
# 1  https://images.gr-assets.com/books/1316637798m...  6066812            98
# 2  https://images.gr-assets.com/books/1360057676m...    89378          1331
# 3  https://s.gr-assets.com/assets/nophoto/book/11...  3209312            11
# 4  https://s.gr-assets.com/assets/nophoto/book/11...  1698376            23
#
#    work_id                                              title  \
# 0   278578                      The Aeneid for Boys and Girls
# 1   701117  All's Fairy in Love and War (Avalon: Web of Ma...
# 2    86259                                         Dog Heaven
# 3  3242879  Moths and Mothers, Feathers and Fathers: A Sto...
# 4  1695373                                    What Do You Do?
#
#                                 title_without_series
# 0                      The Aeneid for Boys and Girls
# 1  All's Fairy in Love and War (Avalon: Web of Ma...
# 2                                         Dog Heaven
# 3  Moths and Mothers, Feathers and Fathers: A Sto...
# 4                                    What Do You Do?
#
# [5 rows x 29 columns]

# %%
# Merge df with goodreads DataFrame

df1 = df.merge(goodreads, how='left', left_on='ISBN', right_on='isbn')
df1.head()
# Out:
#          ISBN    Name  Confidence  \
# 0  0001642081    Text   99.816299
# 1  0001642081    Menu   88.789520
# 2  0001642081   Label   86.814842
# 3  0001642081   Paper   72.812614
# 4  0001642081  Poster   71.399628
#
#                                            Instances  Num_Instances  \
# 0                                                 []              0
# 1  [{'BoundingBox': {'Width': 0.9102855324745178,...              1
# 2                                                 []              0
# 3                                                 []              0
# 4                                                 []              0
#
#          isbn  text_reviews_count    series country_code language_code  ...  \
# 0  0001642081                   4  [265777]           US                ...
# 1  0001642081                   4  [265777]           US                ...
# 2  0001642081                   4  [265777]           US                ...
# 3  0001642081                   4  [265777]           US                ...
# 4  0001642081                   4  [265777]           US                ...
#
#   publication_month edition_information publication_year  \
# 0                                                   1970
# 1                                                   1970
# 2                                                   1970
# 3                                                   1970
# 4                                                   1970
#
#                                                  url  \
# 0  https://www.goodreads.com/book/show/2657015-ba...
# 1  https://www.goodreads.com/book/show/2657015-ba...
# 2  https://www.goodreads.com/book/show/2657015-ba...
# 3  https://www.goodreads.com/book/show/2657015-ba...
# 4  https://www.goodreads.com/book/show/2657015-ba...
#
#                                            image_url  book_id ratings_count  \
# 0  https://images.gr-assets.com/books/1307384593m...  2657015            32
# 1  https://images.gr-assets.com/books/1307384593m...  2657015            32
# 2  https://images.gr-assets.com/books/1307384593m...  2657015            32
# 3  https://images.gr-assets.com/books/1307384593m...  2657015            32
# 4  https://images.gr-assets.com/books/1307384593m...  2657015            32
#
#    work_id                         title          title_without_series
# 0  2681793  Ballet for Laura (Laura, #1)  Ballet for Laura (Laura, #1)
# 1  2681793  Ballet for Laura (Laura, #1)  Ballet for Laura (Laura, #1)
# 2  2681793  Ballet for Laura (Laura, #1)  Ballet for Laura (Laura, #1)
# 3  2681793  Ballet for Laura (Laura, #1)  Ballet for Laura (Laura, #1)
# 4  2681793  Ballet for Laura (Laura, #1)  Ballet for Laura (Laura, #1)
#
# [5 rows x 34 columns]

# %%
# Save df1 to a pickle

df1.to_pickle('BookLabels.pkl')

# %%
df1 = pd.read_pickle('BookLabels.pkl')

# %%
rbg_df = pd.read_csv('average_rbg.csv', index_col=0)

# %%
rbg_df.head()
# Out:
#          isbn        blue       green         red
# 0  1599901927  141.225092  177.505561  215.409007
# 1  8415594828  102.218585  190.058614  187.763558
# 2  0515157635   63.026062   59.296692   59.767029
# 3  0590819194  238.626700  238.833428  238.665763
# 4  0395522781  195.211215  212.979706  219.304641

# %%
histograms_df = pd.read_csv('histograms.csv')

# %%
# Merge df1 with color histograms dataframe and save to pickle

df2 = df1.merge(histograms_df, how='left', left_on='ISBN', right_on='isbn')
df2.to_pickle('BookLabels_Histograms.pkl')

# %%
df3 = df2.merge(rbg_df, how='left', left_on='ISBN', right_on='isbn')

# %%
df3.shape
# Out:
# (66528, 136)

# %%
df3.to_pickle('BookLabels_Histograms_RBG.pkl')
