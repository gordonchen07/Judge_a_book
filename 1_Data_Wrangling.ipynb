# %% [markdown]
# # Data Wrangling Notebook

# %% [markdown]
# ### Overview

# %% [markdown]
# 1) I downloaded the Goodread's children's books from [UCSD Book Graph](https://sites.google.com/eng.ucsd.edu/ucsdbookgraph/home) as a .json file.<br>
# 2) Using [1_getisbn.py](https://github.com/gordonchen07/Judge_a_book/blob/scale_image_collector/Scripts/1_get_isbn.py), I extracted the [ISBN(International Standard Book Number)](https://en.wikipedia.org/wiki/International_Standard_Book_Number) number from the Goodread's dataset and compiled them to isbn.json.<br>
# 3) Next, using [2_getcover.py](https://github.com/gordonchen07/Judge_a_book/blob/scale_image_collector/Scripts/2_get_bookcover.py) to access [Google Books API](https://developers.google.com/books/docs/overview), I retrieved book cover image for the books in isbn.json and saved them to [AWS S3](https://aws.amazon.com/s3/).<br>
# 4) Then, I used [3_analyzeimage.py](https://github.com/gordonchen07/Judge_a_book/blob/scale_image_collector/Scripts/3_analyzeimage.py) to initiate [AWS Rekognition](https://aws.amazon.com/rekognition/) to analyze the book covers for labels and responses were saved in AWS S3 as a json file for each book cover.<br>
# 5) Afterwards, I used [4_get_color_histograms.py](https://github.com/gordonchen07/Judge_a_book/blob/scale_image_collector/Scripts/4_get_color_histograms.py) to compile the color histograms and average color values through the use of [OpenCV](https://opencv-python-tutroals.readthedocs.io/en/latest/py_tutorials/py_imgproc/py_histograms/py_histogram_begins/py_histogram_begins.html) of the book cover images into DataFrames and saved into .csv files.<br>
# 6) Finally, I extract and compiled the relevant image label information from the json files in the steps below.<br>

# %%
import boto3
import json
import pandas as pd
from boto3 import client

# %%
# Get list of Rekognition responses in responses folder of s3 bucket

s3r = boto3.resource('s3')
bucket = s3r.Bucket('judge-a-book')
files_in_bucket = list(bucket.objects.all())

obj_list = [obj.key for obj in files_in_bucket if obj.key.startswith('responses/') and obj.key.endswith('json')]

# %%
# Extract label information from Rekognition responses
conn = client('s3')
res_list = []
for key in obj_list:
    response = conn.get_object(Bucket='judge-a-book', Key=key)
    text = response["Body"].read().decode()
    res_list.append((key, json.loads(text)))

# %%
# Compiles Rekognition label information into DataFrame compatible list format

label_list = []
no_label_list = []
for res in res_list:
    labels = res[1]['Labels']
    if len(labels) == 0:
        ISBN = res[0][10:-5]
        no_label_list.append(ISBN)
    else:
        for label in res[1]['Labels']:
            ISBN = res[0][10:-5]
            Name = label['Name']
            Confidence = label['Confidence']
            Instances = label['Instances']
            numInst = len(label['Instances'])
            label_list.append({'ISBN': ISBN, 
                               'Name': Name, 
                               'Confidence': Confidence, 
                               'Instances': Instances, 
                               'Num_Instances': numInst})
        
# Create DataFrame from label_list and a DataFrame for books without any labels

labels = pd.DataFrame(label_list)
no_labels = pd.DataFrame(no_label_list)

# %%
len(no_labels)
# Out:
# 23

# %% [markdown]
# >Theres 23 book covers that yielded no labels from AWS Rekognition.

# %%
#Examine the first 5 rows of labels DataFrame.

labels.head()
# Out:
#          ISBN    Name  Confidence  \
# 0  0001642081    Text   99.816299
# 1  0001642081    Menu   88.789520
# 2  0001642081   Label   86.814842
# 3  0001642081   Paper   72.812614
# 4  0001642081  Poster   71.399628
#
#                                            Instances  Num_Instances
# 0                                                 []              0
# 1  [{'BoundingBox': {'Width': 0.9102855324745178,...              1
# 2                                                 []              0
# 3                                                 []              0
# 4                                                 []              0

# %%
# Import goodreads' children's books dataframe and examine first 5 rows of data.

goodreads = pd.read_json('goodreads_books_children.json', lines=True)
goodreads.head()
# Out:
#          isbn  text_reviews_count    series country_code language_code  \
# 0  1599150603                   7        []           US
# 1  1934876569                   6  [151854]           US
# 2  0590417010                 193        []           US           eng
# 3  0915190575                   4        []           US
# 4  1416904999                   4        []           US
#
#                                      popular_shelves asin is_ebook  \
# 0  [{'count': '56', 'name': 'to-read'}, {'count':...         false
# 1  [{'count': '515', 'name': 'to-read'}, {'count'...         false
# 2  [{'count': '450', 'name': 'to-read'}, {'count'...         false
# 3  [{'count': '8', 'name': 'to-read'}, {'count': ...         false
# 4  [{'count': '8', 'name': 'to-read'}, {'count': ...         false
#
#    average_rating kindle_asin  ... publication_month edition_information  \
# 0            4.13  B00DU10PUG  ...                 9
# 1            4.22              ...                 3
# ...

# %%
# Merge labels DataFrame with goodreads DataFrame and inspect first 5 rows or merged DataFrame.

labels_goodreads = labels.merge(goodreads, how='left', left_on='ISBN', right_on='isbn')
labels_goodreads.head()
# Out:
#          ISBN    Name  Confidence  \
# 0  0001642081    Text   99.816299
# 1  0001642081    Menu   88.789520
# 2  0001642081   Label   86.814842
# 3  0001642081   Paper   72.812614
# 4  0001642081  Poster   71.399628
#
#                                            Instances  Num_Instances  \
# 0                                                 []              0
# 1  [{'BoundingBox': {'Width': 0.9102855324745178,...              1
# 2                                                 []              0
# 3                                                 []              0
# 4                                                 []              0
#
#          isbn  text_reviews_count    series country_code language_code  ...  \
# 0  0001642081                   4  [265777]           US                ...
# 1  0001642081                   4  [265777]           US                ...
# 2  0001642081                   4  [265777]           US                ...
# ...

# %%
# Save df1 to a pickle

df1.to_pickle('BookLabels.pkl')

# %%
df1 = pd.read_pickle('BookLabels.pkl')

# %%
#Load 

rbg_df = pd.read_csv('average_rbg.csv', index_col=0)

# %%
rbg_df.head()
# Out:
#          isbn        blue       green         red
# 0  1599901927  141.225092  177.505561  215.409007
# 1  8415594828  102.218585  190.058614  187.763558
# 2  0515157635   63.026062   59.296692   59.767029
# 3  0590819194  238.626700  238.833428  238.665763
# 4  0395522781  195.211215  212.979706  219.304641

# %%
histograms_df = pd.read_csv('histograms.csv')

# %%
# Merge df1 with color histograms dataframe and save to pickle

df2 = df1.merge(histograms_df, how='left', left_on='ISBN', right_on='isbn')
df2.to_pickle('BookLabels_Histograms.pkl')

# %%
df3 = df2.merge(rbg_df, how='left', left_on='ISBN', right_on='isbn')

# %%
df3.shape
# Out:
# (66528, 136)

# %%
df3.to_pickle('BookLabels_Histograms_RBG.pkl')

# %% [markdown]
# The next step is to explore the data we have compiled and conduct our analysis in [2_Data_Exploration.ipynb](https://github.com/gordonchen07/Judge_a_book/blob/scale_image_collector/2_Data%20Exploration.ipynb).
